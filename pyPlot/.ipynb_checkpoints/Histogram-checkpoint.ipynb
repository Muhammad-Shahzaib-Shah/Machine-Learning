# %%
import matplotlib.pyplot as plt
std_scr = [60,64,65,63,70,74,75,80,83,88,89,85,54,82,81,87,90,96,98,97,96,95,94,93,92,91,100,111,102,107]
plt.hist(std_scr, bins =5,color= 'purple', edgecolor='black')
plt.xlabel("Score Range")
plt.ylabel("Numbers of Students")
plt.title("Score Distribution of Students")
plt.show()
